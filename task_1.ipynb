# %% [markdown]
# # Task 1: Building a Transactional Database in Google Big Query
#
# For this portion of the project, we will use the cleaned data files from the Wedge zipped files and upload them to Google BigQuery.

# %%
import os
import pandas as pd
from google.cloud import bigquery
from google.oauth2 import service_account
from google.cloud.bigquery import LoadJobConfig

# %%
# Google BigQuery Config
project_id = 'niekampbreannawedge'
dataset_id = 'wedge24'

# %%
client = bigquery.Client(project=project_id)

# %%
data_directory = "data/clean-files"
files = os.listdir(data_dir)
print(files)
# Out:
# ['transArchive_201001_201003_clean.csv', 'transArchive_201004_201006_clean.csv', 'transArchive_201007_201009_clean.csv', 'transArchive_201010_201012_clean.csv', 'transArchive_201101_201103_clean.csv', 'transArchive_201104_clean.csv', 'transArchive_201105_clean.csv', 'transArchive_201106_clean.csv', 'transArchive_201107_201109_clean.csv', 'transArchive_201110_201112_clean.csv', 'transArchive_201201_201203_clean.csv', 'transArchive_201201_201203_inactive_clean.csv', 'transArchive_201204_201206_clean.csv', 'transArchive_201204_201206_inactive_clean.csv', 'transArchive_201207_201209_clean.csv', 'transArchive_201207_201209_inactive_clean.csv', 'transArchive_201210_201212_clean.csv', 'transArchive_201210_201212_inactive_clean.csv', 'transArchive_201301_201303_clean.csv', 'transArchive_201301_201303_inactive_clean.csv', 'transArchive_201304_201306_clean.csv', 'transArchive_201304_201306_inactive_clean.csv', 'transArchive_201307_201309_clean.csv', 'transArchive_201307_201309_inactive_clean.csv', 'transArchive_201310_201312_clean.csv', 'transArchive_201310_201312_inactive_clean.csv', 'transArchive_201401_201403_clean.csv', 'transArchive_201401_201403_inactive_clean.csv', 'transArchive_201404_201406_clean.csv', 'transArchive_201404_201406_inactive_clean.csv', 'transArchive_201407_201409_clean.csv', 'transArchive_201407_201409_inactive_clean.csv', 'transArchive_201410_201412_clean.csv', 'transArchive_201410_201412_inactive_clean.csv', 'transArchive_201501_201503_clean.csv', 'transArchive_201504_201506_clean.csv', 'transArchive_201507_201509_clean.csv', 'transArchive_201510_clean.csv', 'transArchive_201511_clean.csv', 'transArchive_201512_clean.csv', 'transArchive_201601_clean.csv', 'transArchive_201602_clean.csv', 'transArchive_201603_clean.csv', 'transArchive_201604_clean.csv', 'transArchive_201605_clean.csv', 'transArchive_201606_clean.csv', 'transArchive_201607_clean.csv', 'transArchive_201608_clean.csv', 'transArchive_201609_clean.csv', 'transArchive_201610_clean.csv', 'transArchive_201611_clean.csv', 'transArchive_201612_clean.csv', 'transArchive_201701_clean.csv']

# %%
# BigQuery schema
schema = [
    bigquery.SchemaField("datetime", "TIMESTAMP", mode="NULLABLE"),
    bigquery.SchemaField("register_no", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("emp_no", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("trans_no", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("upc", "STRING", mode="NULLABLE"),
    bigquery.SchemaField("description", "STRING", mode="NULLABLE"),
    bigquery.SchemaField("trans_type", "STRING", mode="NULLABLE"),
    bigquery.SchemaField("trans_subtype", "STRING", mode="NULLABLE"),
    bigquery.SchemaField("trans_status", "STRING", mode="NULLABLE"),
    bigquery.SchemaField("department", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("quantity", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("Scale", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("cost", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("unitPrice", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("total", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("regPrice", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("altPrice", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("tax", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("taxexempt", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("foodstamp", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("wicable", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("discount", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("memDiscount", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("discountable", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("discounttype", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("voided", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("percentDiscount", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("ItemQtty", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("volDiscType", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("volume", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("VolSpecial", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("mixMatch", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("matched", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("memType", "BOOLEAN", mode="NULLABLE"),
    bigquery.SchemaField("staff", "BOOLEAN", mode="NULLABLE"),
    bigquery.SchemaField("numflag", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("itemstatus", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("tenderstatus", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("charflag", "STRING", mode="NULLABLE"),
    bigquery.SchemaField("varflag", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("batchHeaderID", "BOOLEAN", mode="NULLABLE"),
    bigquery.SchemaField("local", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("organic", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("display", "BOOLEAN", mode="NULLABLE"),
    bigquery.SchemaField("receipt", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("card_no", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("store", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("branch", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("match_id", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("trans_id", "FLOAT", mode="NULLABLE"),
]

# %%
# Configure job settings
job_config = bigquery.LoadJobConfig(
    schema=schema,
    source_format=bigquery.SourceFormat.CSV,
    skip_leading_rows=1,
    write_disposition=bigquery.WriteDisposition.WRITE_TRUNCATE,  # Replace table if it exists
)

# %%
# Upload each file
files = os.listdir(data_directory)

for file_name in files:
    if file_name.endswith("_clean.csv"):  # Match cleaned files
        file_path = os.path.join(data_directory, file_name)
        table_name = file_name.replace("_clean.csv", "")  # Remove suffix
        table_id = f"{project_id}.{dataset_id}.{table_name}"  # Full table name

        print(f"Uploading {file_name} to BigQuery table {table_id}...")

        # Upload file to BigQuery
        with open(file_path, "rb") as source_file:
            job = client.load_table_from_file(source_file, table_id, job_config=job_config)
            job.result()  # Wait for the job to complete
            print(f"Uploaded {file_name} successfully to {table_id}!")
# Out:
# Uploading transArchive_201001_201003_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201001_201003...
# Uploaded transArchive_201001_201003_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201001_201003!
# Uploading transArchive_201004_201006_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201004_201006...
# Uploaded transArchive_201004_201006_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201004_201006!
# Uploading transArchive_201007_201009_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201007_201009...
# Uploaded transArchive_201007_201009_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201007_201009!
# Uploading transArchive_201010_201012_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201010_201012...
# Uploaded transArchive_201010_201012_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201010_201012!
# Uploading transArchive_201101_201103_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201101_201103...
# Uploaded transArchive_201101_201103_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201101_201103!
# Uploading transArchive_201104_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201104...
# Uploaded transArchive_201104_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201104!
# Uploading transArchive_201105_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201105...
# Uploaded transArchive_201105_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201105!
# Uploading transArchive_201106_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201106...
# Uploaded transArchive_201106_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201106!
# Uploading transArchive_201107_201109_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201107_201109...
# Uploaded transArchive_201107_201109_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201107_201109!
# Uploading transArchive_201110_201112_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201110_201112...
# Uploaded transArchive_201110_201112_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201110_201112!
# Uploading transArchive_201201_201203_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201201_201203...
# Uploaded transArchive_201201_201203_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201201_201203!
# Uploading transArchive_201201_201203_inactive_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201201_201203_inactive...
# Uploaded transArchive_201201_201203_inactive_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201201_201203_inactive!
# Uploading transArchive_201204_201206_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201204_201206...
# Uploaded transArchive_201204_201206_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201204_201206!
# Uploading transArchive_201204_201206_inactive_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201204_201206_inactive...
# Uploaded transArchive_201204_201206_inactive_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201204_201206_inactive!
# Uploading transArchive_201207_201209_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201207_201209...
# Uploaded transArchive_201207_201209_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201207_201209!
# Uploading transArchive_201207_201209_inactive_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201207_201209_inactive...
# Uploaded transArchive_201207_201209_inactive_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201207_201209_inactive!
# Uploading transArchive_201210_201212_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201210_201212...
# Uploaded transArchive_201210_201212_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201210_201212!
# Uploading transArchive_201210_201212_inactive_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201210_201212_inactive...
# Uploaded transArchive_201210_201212_inactive_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201210_201212_inactive!
# Uploading transArchive_201301_201303_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201301_201303...
# Uploaded transArchive_201301_201303_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201301_201303!
# Uploading transArchive_201301_201303_inactive_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201301_201303_inactive...
# Uploaded transArchive_201301_201303_inactive_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201301_201303_inactive!
# Uploading transArchive_201304_201306_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201304_201306...
# Uploaded transArchive_201304_201306_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201304_201306!
# Uploading transArchive_201304_201306_inactive_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201304_201306_inactive...
# Uploaded transArchive_201304_201306_inactive_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201304_201306_inactive!
# Uploading transArchive_201307_201309_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201307_201309...
# Uploaded transArchive_201307_201309_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201307_201309!
# Uploading transArchive_201307_201309_inactive_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201307_201309_inactive...
# Uploaded transArchive_201307_201309_inactive_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201307_201309_inactive!
# Uploading transArchive_201310_201312_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201310_201312...
# Uploaded transArchive_201310_201312_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201310_201312!
# Uploading transArchive_201310_201312_inactive_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201310_201312_inactive...
# Uploaded transArchive_201310_201312_inactive_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201310_201312_inactive!
# Uploading transArchive_201401_201403_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201401_201403...
# Uploaded transArchive_201401_201403_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201401_201403!
# Uploading transArchive_201401_201403_inactive_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201401_201403_inactive...
# Uploaded transArchive_201401_201403_inactive_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201401_201403_inactive!
# Uploading transArchive_201404_201406_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201404_201406...
# Uploaded transArchive_201404_201406_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201404_201406!
# Uploading transArchive_201404_201406_inactive_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201404_201406_inactive...
# Uploaded transArchive_201404_201406_inactive_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201404_201406_inactive!
# Uploading transArchive_201407_201409_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201407_201409...
# Uploaded transArchive_201407_201409_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201407_201409!
# Uploading transArchive_201407_201409_inactive_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201407_201409_inactive...
# Uploaded transArchive_201407_201409_inactive_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201407_201409_inactive!
# Uploading transArchive_201410_201412_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201410_201412...
# Uploaded transArchive_201410_201412_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201410_201412!
# Uploading transArchive_201410_201412_inactive_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201410_201412_inactive...
# Uploaded transArchive_201410_201412_inactive_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201410_201412_inactive!
# Uploading transArchive_201501_201503_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201501_201503...
# Uploaded transArchive_201501_201503_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201501_201503!
# Uploading transArchive_201504_201506_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201504_201506...
# Uploaded transArchive_201504_201506_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201504_201506!
# Uploading transArchive_201507_201509_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201507_201509...
# Uploaded transArchive_201507_201509_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201507_201509!
# Uploading transArchive_201510_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201510...
# Uploaded transArchive_201510_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201510!
# Uploading transArchive_201511_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201511...
# Uploaded transArchive_201511_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201511!
# Uploading transArchive_201512_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201512...
# Uploaded transArchive_201512_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201512!
# Uploading transArchive_201601_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201601...
# Uploaded transArchive_201601_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201601!
# Uploading transArchive_201602_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201602...
# Uploaded transArchive_201602_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201602!
# Uploading transArchive_201603_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201603...
# Uploaded transArchive_201603_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201603!
# Uploading transArchive_201604_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201604...
# Uploaded transArchive_201604_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201604!
# Uploading transArchive_201605_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201605...
# Uploaded transArchive_201605_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201605!
# Uploading transArchive_201606_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201606...
# Uploaded transArchive_201606_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201606!
# Uploading transArchive_201607_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201607...
# Uploaded transArchive_201607_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201607!
# Uploading transArchive_201608_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201608...
# Uploaded transArchive_201608_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201608!
# Uploading transArchive_201609_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201609...
# Uploaded transArchive_201609_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201609!
# Uploading transArchive_201610_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201610...
# Uploaded transArchive_201610_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201610!
# Uploading transArchive_201611_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201611...
# Uploaded transArchive_201611_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201611!
# Uploading transArchive_201612_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201612...
# Uploaded transArchive_201612_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201612!
# Uploading transArchive_201701_clean.csv to BigQuery table niekampbreannawedge.wedge24.transArchive_201701...
# Uploaded transArchive_201701_clean.csv successfully to niekampbreannawedge.wedge24.transArchive_201701!
